# %%
import pandas as pd
import plotly.graph_objs as go
import numpy as np
import plotly.express as px

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Healthy is happier?

# %%
#load csv-file
df = pd.read_csv("world-happiness-report-2021.csv")
df_all_time = pd.read_csv("world-happiness-report.csv")

# %%
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# #### vergelijking blijheid verschillende landen

# %%
world_map = go.Figure(px.scatter_geo(df, locations = df["Country name"], color = df["Regional indicator"]))
world_map.update_geos(projection_type="natural earth")
world_map.update_layout(height = 300, margin={"r":1, "t": 0, "l": 2,"b": 4})
# Out:
# <div>                            <div id="9a46db6f-9825-470f-919d-aaaf58594ab8" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a46db6f-9825-470f-919d-aaaf58594ab8")) {                    Plotly.newPlot(                        "9a46db6f-9825-470f-919d-aaaf58594ab8",                        [{"geo":"geo","hovertemplate":"Regional indicator=Western Europe<br>Country name=%{location}<extra></extra>","legendgroup":"Western Europe","locations":["Finland","Denmark","Switzerland","Iceland","Netherlands","Norway","Sweden","Luxembourg","Austria","Germany","Ireland","United Kingdom","Belgium","France","Malta","Spain","Italy","Cyprus","Portugal","Greece","North Cyprus"],"marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Western Europe","sh
# ...

# %%
help(go.Scattergeo)
# Out:
# Help on class Scattergeo in module plotly.graph_objs._scattergeo:
#
# class Scattergeo(plotly.basedatatypes.BaseTraceType)
#  |  Scattergeo(arg=None, connectgaps=None, customdata=None, customdatasrc=None, featureidkey=None, fill=None, fillcolor=None, geo=None, geojson=None, hoverinfo=None, hoverinfosrc=None, hoverlabel=None, hovertemplate=None, hovertemplatesrc=None, hovertext=None, hovertextsrc=None, ids=None, idssrc=None, lat=None, latsrc=None, legendgroup=None, legendgrouptitle=None, legendrank=None, line=None, locationmode=None, locations=None, locationssrc=None, lon=None, lonsrc=None, marker=None, meta=None, metasrc=None, mode=None, name=None, opacity=None, selected=None, selectedpoints=None, showlegend=None, stream=None, text=None, textfont=None, textposition=None, textpositionsrc=None, textsrc=None, texttemplate=None, texttemplatesrc=None, uid=None, uirevision=None, unselected=None, visible=None, **kwargs)
#  |
#  |  Method resolution order:
#  |      Scattergeo
# ...
